# %%
from pyspark.sql.functions import current_timestamp

# %%
Table='project_mobility.bronze.fuel_price_raw'

df=spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("/Volumes/project_mobility/bronze/my_local_files/fuel_prices_2025.csv")

df=df.withColumn("ingestion_timestamp",current_timestamp())

#display(df )

df.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable(Table)
